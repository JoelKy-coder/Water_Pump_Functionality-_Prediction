# %% [markdown]
# # Notebook 02 — Data Cleaning & Feature Engineering
#
# This notebook applies the documented cleaning decisions, engineers date-related features, and writes the processed dataset to the expected path.

# %%
import sys, pathlib
ROOT = pathlib.Path.cwd().resolve()
if not (ROOT / 'src').exists():
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
print('Added repository root to sys.path:', ROOT)

# %%
from src.data_loader import load_merged_data
from src.preprocessing import clean_dataframe
from src.config import PROCESSED_DIR

raw_df = load_merged_data()
clean_df = clean_dataframe(raw_df)
clean_df.to_csv(PROCESSED_DIR / 'train_clean.csv', index=False)
clean_df.head()

# %%
print('Clean shape:', clean_df.shape)
print('Missing values after cleaning:\n', clean_df.isna().sum().sort_values(ascending=False).head(20).to_string())
print('Columns:\n', clean_df.columns.tolist())
print('Target distribution:\n', clean_df['status_group'].value_counts().to_string())
