# %% [markdown]
# # Notebook 04 — Modelling
#
# This notebook trains a benchmark set of models with the shared preprocessing pipeline and compares cross-validated weighted F1 across models.

# %%
import sys, pathlib
ROOT = pathlib.Path.cwd().resolve()
if not (ROOT / 'src').exists():
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
print('Added repository root to sys.path:', ROOT)

# %%
from src.data_loader import load_merged_data
from src.preprocessing import clean_dataframe, encode_target
import pandas as pd

raw_df = load_merged_data()
clean_df = clean_dataframe(raw_df)
encoded_df, _ = encode_target(clean_df)
print('Encoded shape:', encoded_df.shape)

# %%
from src.model_training import train_and_select_model
results, metadata, best_model = train_and_select_model(encoded_df)
print('CV results:\n', pd.DataFrame(results).T.sort_values('cv_weighted_f1_mean', ascending=False).to_string())
print('Selected model:', metadata['best_model_name'])
